# %% [markdown]
# 1.   Method = .append()
# 2.   Atribute = .shape
# 3.   Function = len()
#
# untuk function, bisa ditulis di class lain
# untuk method, bisa harus di tulis di class itu aja
#
# CONTOH METHOD:
#
# class
#   **def append()**
#
#
# contoh FUNCTION:
#
# **def print:**
#
# class
#  def append()

# %% [markdown]
# # Seputar Python
# - Case Sensitive, contoh: "Python" != "python"
# - interpreter & Compiler
# - Tidak perlu tanda ; diakhir code
# - tidak perlu curly bracket {}, melainkan menggunakan tab (4 space) untuk definisi function

# %%
print("print berguna untuk menampilkan proses maupun output program ke layar")
# Out:
# print berguna untuk menampilkan proses maupun output program ke layar

# %% [markdown]
# # Tipe Data di Python
# ### Tunggal
# - Numerik: Integer (bil bulat) & Float (bil decimal)
# - String (huruf/kata/kalimat)
# - Boolean (True or False)
#
# ### Jamak
# - Lists (kumpulan elemen yang dapat diubah)
# - Dictionaries (sekumpulan koentji dan Nilai)
# - Sets (himpunan)
# - Tuples (kumpulan elemen yang tidak dapat diubah)

# %% [markdown]
# # Variabel
# - sesuatu yang dapat diisi
# <br>
# <br>
# <img width= "250" src="https://www.dynamicdiscs.com/v/vspfiles/photos/5007-2.jpg">
# <br>
# <br>
# - memiliki kaidah penulisan yang dapat ditulis dengan huruf, angka dan underscore.
# - angka tidak boleh ditaro diawal penamaan, hanya huruf & nama yg diperbolehkan

# %% [markdown]
# # Numerik
# - Integer
# - Float

# %%
# ini comment
bil_bulat=7 # integer
print(bil_bulat)
bil_desimal=3.14 # float
print(bil_desimal)
# Out:
# 7
# 3.14

# %%
# Operasi Matematika
x, y =11,2

#add

#subtract

#product

#division

#Modulo

#Power

#Root

# %% [markdown]
# # String

# %%
kalimat='ini juga string' #string with single quotes
print(kalimat)
print("\n") # ini enter

kalimat="ini string" #string with double quotes
print(kalimat)
print("\n")

kalimat="""ini juga string 
tapi bisa dienter""" # string with triple quotes (multilines string)
print(kalimat)
print("\n")
# Out:
# ini juga string
#
#
# ini string
#
#
# ini juga string
# tapi bisa dienter

# %%
kalimat="untuk menjadi pawang uler, kita harus bisa bahasa 'python'"
print(kalimat)
kalimat='untuk menjadi pawang uler, kita harus bisa bahasa "python"'# escape character
print(kalimat)
kalimat="""untuk menjadi pawang uler, kita harus bisa bahasa "python" """
print(kalimat)
# Out:
# untuk menjadi pawang uler, kita harus bisa bahasa 'python'
# untuk menjadi pawang uler, kita harus bisa bahasa "python"
# untuk menjadi pawang uler, kita harus bisa bahasa "python"

# %%
# String Concatenation * +
kata="Kobra"
kata+" "+kata
# Out:
# 'Kobra Kobra'

# %%
uler = 'python'
expertise = 'pawang uler'
print(f"untuk menjadi '{expertise}' kita harus bisa bahasa {uler}")
# Out:
# untuk menjadi 'pawang uler' kita harus bisa bahasa python

# %% [markdown]
# # Latihan
# <br>
# <img src="https://media.matamata.com/thumbs/2021/03/22/73000-irene-sukandar-vs-dewa-kipas-youtubecom/o-img-73000-irene-sukandar-vs-dewa-kipas-youtubecom.jpg" width=250>
# <br>
# Buatlah sebuah program yang meghitung luas segitiga  dengan detail<br>
#
# - nama variabel tinggi
# - nama variabel alas
# - nama variabel luas_segitiga
# - output --> Luas Segitiga : hasil

# %%
#put your code
tinggi = float(input())
alas = float(input())
luas_segitiga = (alas*tinggi)/2.0
print("hasil : {}".format(luas_segitiga))
# Out:
# 23.556
# 11.263
# hasil : 132.655614

# %% [markdown]
# # Lists
# List adalah data structure yang bersifat mutable, changeable, ordered by index, dan dapat menyimpan tipe data apapun.
#
# <img src="https://www.sitesbay.com/cprogramming/images/c-array.png">

# %%
makanan=["kerang","usus","kangkung","tempe"]
kantong_doraemon=["senter pembesar",1,3.14,True]

# %%
# List Operation * +
print(makanan + kantong_doraemon)
# Out:
# ['kerang', 'usus', 'kangkung', 'tempe', 'senter pembesar', 1, 3.14, True]

# %% [markdown]
# ### Akses Elemen List

# %%
print(kantong_doraemon[0])
print(kantong_doraemon[-1])
print(makanan[3])
print(makanan[-1])
# Out:
# senter pembesar
# True
# tempe
# tempe

# %% [markdown]
# ### Slicing List
# LIST[include:exclude]

# %%
print(kantong_doraemon[0:3])
print(kantong_doraemon[:3])
# Out:
# ['senter pembesar', 1, 3.14]
# ['senter pembesar', 1, 3.14]

# %%
print(kantong_doraemon[:])
print(kantong_doraemon)
# Out:
# ['senter pembesar', 1, 3.14, True]
# ['senter pembesar', 1, 3.14, True]

# %%
print(kantong_doraemon[-2::-1])
# Out:
# [3.14, 1, 'senter pembesar']

# %% [markdown]
# ### Modifikasi Elemen List

# %%
kantong_doraemon[0]="senter biasa"
makanan[0]="siomay"
makanan[1]="seblak"
makanan[2]="cimol"
makanan[3]="kentang"
print(kantong_doraemon)
print(makanan)
# Out:
# ['senter biasa', 1, 3.14, True]
# ['siomay', 'seblak', 'cimol', 'kentang']

# %% [markdown]
# ### Menambahkan elemen ke List
# - Menggunakan method .append
# https://docs.python.org/3/tutorial/datastructures.html

# %%
kantong_doraemon.append("pintu kemana saja")
print(kantong_doraemon)
# Out:
# ['senter biasa', 1, 3.14, True, 'pintu kemana saja']

# %% [markdown]
# ### Menghapus Elemen List

# %%
del(kantong_doraemon[3])
print(kantong_doraemon)
# Out:
# ['senter biasa', 1, 3.14, 'pintu kemana saja']

# %%
del(kantong_doraemon[2])
print(kantong_doraemon)
# Out:
# ['senter biasa', 1, 'pintu kemana saja']

# %% [markdown]
# ### List in lists

# %%
Doraemon=[["Doraemon","Nobita","Giant","Suneo"],
          [],
          [60,50,80,45]]

# %%
# Akses elemen
print(Doraemon[0])
print(Doraemon[0][2])
# Out:
# ['Doraemon', 'Nobita', 'Giant', 'Suneo']
# Giant

# %%
#ubah elemen
Doraemon[0][2]="Shizuka"
print(Doraemon[0])
# Out:
# ['Doraemon', 'Nobita', 'Shizuka', 'Suneo']

# %%
# Keterbatasan List
Doraemon[0][:2]
# Doraemon[0:2][:2]
# Out:
# ['Doraemon', 'Nobita']

# %%
#hapus elemen
del(Doraemon[0][2])
print(Doraemon[0])
# Out:
# ['Doraemon', 'Nobita', 'Suneo']

# %%
del(Doraemon[0])
print(Doraemon)
# Out:
# [[], [60, 50, 80, 45]]

# %% [markdown]
# # Latihan
# <br>
# <img src="https://media.matamata.com/thumbs/2021/03/22/73000-irene-sukandar-vs-dewa-kipas-youtubecom/o-img-73000-irene-sukandar-vs-dewa-kipas-youtubecom.jpg" width=250>
# <br>
#
# - Buatlah sebuah program dengan output "Doraemon sering makan Dorayaki sehingga berat badannya menjadi 70 Kg padahal dia robot"
#
# - Buat output tersebut dengan menggunakan list dibawah ini

# %%
Doraemon=[["Doraemon","Nobita","Giant","Suneo"],[],[70,50,80,45]]

# Put your code
tokoh = Doraemon[0][0]
berat = Doraemon[2][0]
print(f"{tokoh} sering makan Dorayaki sehingga berat badannya menjadi {berat} Kg padahal dia robot")
# Out:
# Doraemon sering makan Dorayaki sehingga berat badannya menjadi 70 Kg padahal dia robot

# %% [markdown]
# # Dictionaries
# Dictionary adalah data structure untuk menyimpan data jenis key-value pairs. Biasanya digunakan untuk menyimpan data yang memilki relasi/kemiripan seperti menyimpan sebuah informasi user yang berisi ID, username, age, dll.

# %%
karakter_doraemon={"Doraemon":"Robot","Nobita":"Human","Giant":"Human","Suneo":"Human"}

# %% [markdown]
# ### Akses Elemen Dict

# %%
print(karakter_doraemon["Doraemon"])
print(karakter_doraemon["Nobita"])
# Out:
# Robot
# Human

# %% [markdown]
# ### Modifikasi Elemen Dict

# %%
karakter_doraemon["Nobita"]="Cyborg"

# %% [markdown]
# ### Menambahkan Elemen Dict

# %%
karakter_doraemon["Shizuka"]="Human"

# %% [markdown]
# ### Method dalam Dict
# - dict.keys()
# - dict.values()
# - dict.items()
# - https://docs.python.org/3/library/stdtypes.html#typesmapping

# %%
print(karakter_doraemon.keys())
print(karakter_doraemon.values())
print(karakter_doraemon.items())
# Out:
# dict_keys(['Doraemon', 'Nobita', 'Giant', 'Suneo', 'Shizuka'])
# dict_values(['Robot', 'Cyborg', 'Human', 'Human', 'Human'])
# dict_items([('Doraemon', 'Robot'), ('Nobita', 'Cyborg'), ('Giant', 'Human'), ('Suneo', 'Human'), ('Shizuka', 'Human')])

# %%
print(type(karakter_doraemon.keys()))
# Out:
# <class 'dict_keys'>

# %% [markdown]
# ## Menghapus Elemen Dict

# %%
del(karakter_doraemon["Nobita"])
print(karakter_doraemon)
# Out:
# {'Doraemon': 'Robot', 'Giant': 'Human', 'Suneo': 'Human', 'Shizuka': 'Human'}

# %% [markdown]
# ## Dictionary in Dictionaries

# %%
karakter_doraemon={"Doraemon":{"Race":"Robot","Food":"Dorayaki"},"Nobita":{"Race":"Human","Food":"Nasi Kebuli"},
                   "Giant":{"Race":"Human","Food":"Pecel Ayam"},"Suneo":{"Race":"Human","Food":"Gado-gado"}}

# %%
#Akses Elemen
print(karakter_doraemon["Doraemon"]["Food"])
print(karakter_doraemon["Doraemon"]["Race"])
# Out:
# Dorayaki
# Robot

# %%
#Ubah Elemen
karakter_doraemon["Doraemon"]["Food"]="Bakso"
print(karakter_doraemon["Doraemon"]["Food"])
# Out:
# Bakso

# %%
#tambah elemen
karakter_doraemon["Doraemon"]["minuman"]="jus"

# %%
karakter_doraemon["Shizuka"]={"Race":"Human","Food":"Kurma"}

# %%
karakter_doraemon["Shizuka"]["minuman"]="jus"

# %%
karakter_doraemon
# Out:
# {'Doraemon': {'Food': 'Bakso', 'Race': 'Robot', 'minuman': 'jus'},
#  'Giant': {'Food': 'Pecel Ayam', 'Race': 'Human'},
#  'Nobita': {'Food': 'Nasi Kebuli', 'Race': 'Human'},
#  'Shizuka': {'Food': 'Kurma', 'Race': 'Human', 'minuman': 'jus'},
#  'Suneo': {'Food': 'Gado-gado', 'Race': 'Human'}}

# %%
karakter_doraemon["Shizuka"]["minuman"]="jus"

# %%
#Hapus elemen
del(karakter_doraemon["Shizuka"]["minuman"])
karakter_doraemon
# Out:
# {'Doraemon': {'Food': 'Bakso', 'Race': 'Robot', 'minuman': 'jus'},
#  'Giant': {'Food': 'Pecel Ayam', 'Race': 'Human'},
#  'Nobita': {'Food': 'Nasi Kebuli', 'Race': 'Human'},
#  'Shizuka': {'Food': 'Kurma', 'Race': 'Human'},
#  'Suneo': {'Food': 'Gado-gado', 'Race': 'Human'}}

# %%
del(karakter_doraemon["Shizuka"])
karakter_doraemon
# Out:
# {'Doraemon': {'Food': 'Bakso', 'Race': 'Robot', 'minuman': 'jus'},
#  'Giant': {'Food': 'Pecel Ayam', 'Race': 'Human'},
#  'Nobita': {'Food': 'Nasi Kebuli', 'Race': 'Human'},
#  'Suneo': {'Food': 'Gado-gado', 'Race': 'Human'}}

# %% [markdown]
# # Latihan
# <br>
# <img src="https://media.matamata.com/thumbs/2021/03/22/73000-irene-sukandar-vs-dewa-kipas-youtubecom/o-img-73000-irene-sukandar-vs-dewa-kipas-youtubecom.jpg" width=250>
# <br>
#
# - Buatlah sebuah program dengan output "Makanan kesukaan Nobita adalah nasi kebuli, selaras dengan nasibnya yg sering dibuli oleh Giant dan Suneo"
#
# - Buat output tersebut dengan menggunakan Dictionaries dibawah ini

# %%
karakter_doraemon={"Doraemon":{"Race":"Robot","Food":"Dorayaki"},"Nobita":{"Race":"Human","Food":"Nasi Kebuli"},
                   "Giant":{"Race":"Human","Food":"Pecel Ayam"},"Suneo":{"Race":"Human","Food":"Gado-gado"}}

#put your code

list_tokoh = list(karakter_doraemon.keys())
nbt = list_tokoh[1]
gt = list_tokoh[2]
sno = list_tokoh[3]
  

nk = karakter_doraemon["Nobita"]["Food"]
print(f"Makanan kesukaan {nbt} adalah {nk}, selaras dengan nasibnya yg sering dibuli oleh {gt} dan {sno}")
# Out:
# Makanan kesukaan Nobita adalah Nasi Kebuli, selaras dengan nasibnya yg sering dibuli oleh Giant dan Suneo

# %% [markdown]
# # Tuples
# Tuples adalah data structures yang mirip seperti List namun bersifat immutable, unchangeable, ordered sequence by index, dan dapat menyimpan tipe data apapun.

# %%
makanan=("kerang","usus","kangkung","tempe")
kantong_doraemon=("senter pembesar",1,3.14,True)

# %%
#Tuples Operation * +
print(makanan + kantong_doraemon)
# Out:
# ('kerang', 'usus', 'kangkung', 'tempe', 'senter pembesar', 1, 3.14, True)

# %% [markdown]
# ### Akses Elemen Tuples

# %%
print(kantong_doraemon[0])
# Out:
# senter pembesar

# %% [markdown]
# ## Slicing Tuples
# Tuples[include:exclude]

# %%
print(kantong_doraemon[0:3])
print(kantong_doraemon[:3])
# Out:
# ('senter pembesar', 1, 3.14)
# ('senter pembesar', 1, 3.14)

# %%
print(kantong_doraemon[:])
print(kantong_doraemon)
# Out:
# ('senter pembesar', 1, 3.14, True)
# ('senter pembesar', 1, 3.14, True)

# %%
print(kantong_doraemon[-2::-1])
# Out:
# (3.14, 1, 'senter pembesar')

# %% [markdown]
# ## Menghapus Tuples

# %%
del(makanan)

# %% [markdown]
# ## Tuple in Tuples

# %%
Doraemon=(("Doraemon","Nobita","Giant","Suneo"),("Dorayaki","Nasi Kebuli","Pecel Ayam","Gado-gado"),(60,50,80,45))

# %%
# Akses elemen
print(Doraemon[0])
print(Doraemon[0][2])
# Out:
# ('Doraemon', 'Nobita', 'Giant', 'Suneo')
# Giant

# %%
del(Doraemon)
print(Doraemon)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-54-9dbce1462803> in <module>()
#       1 del(Doraemon)
# ----> 2 print(Doraemon)
#
# NameError: name 'Doraemon' is not defined

# %% [markdown]
# # Latihan
# <br>
# <img src="https://media.matamata.com/thumbs/2021/03/22/73000-irene-sukandar-vs-dewa-kipas-youtubecom/o-img-73000-irene-sukandar-vs-dewa-kipas-youtubecom.jpg" width=250>
# <br>
#
# - Buatlah sebuah program dengan output ""Doraemon sering makan Dorayaki sehingga berat badannya menjadi 70 Kg, padahal dia robot"
#
# - Buat output tersebut dengan menggunakan Tuples dibawah ini

# %%
Doraemon=(("Doraemon","Nobita","Giant","Suneo"),("Dorayaki","Nasi Kebuli","Pecel Ayam","Gado-gado"),(70,50,80,45))

#put your code
dremn = Doraemon[0][0]
dryk = Doraemon[1][0]
bb = Doraemon[2][0]
print(f"{dremn} sering makan {dryk} sehingga berat badannya menjadi {bb} Kg, padahal dia robot")
# Out:
# Doraemon sering makan Dorayaki sehingga berat badannya menjadi 70 Kg, padahal dia robot

# %% [markdown]
# # Sets
# - Sets adalah data structure yang kalau kita analogikan bentuknya seperti diagram himpunan pada matematika.
#
# Sifat dari Set sendiri yaitu:
# - Kumpulan dari item yang tidak berurutan
# - Setiap item harus unik. Tidak boleh duplikat
# - Immutable or unchangeable
# - Dapat digunakan untuk operasi himpunan seperti Union,Intersection, dll.

# %%
makanan=set()
makanan= {1,2,3,4,"Lima"}

# %%
print(makanan)
# Out:
# {1, 2, 3, 4, 'Lima'}

# %% [markdown]
# Built-in Function dalam Set:
# - add() untuk menambah 1 elemen
# - update() untuk menambah multiple elemen
# - remove() untuk menghapus elemen dan mengembalikan nilai kembalian error jika ada

# %%
makanan.add(6)

# %%
print(makanan)
# Out:
# {1, 2, 3, 4, 'Lima', 6}

# %%
makanan.update(["tujuh",8])

# %%
print(makanan)
# Out:
# {1, 2, 3, 4, 'Lima', 6, 'tujuh', 8}

# %%
makanan.remove("tujuh")

# %%
print(makanan)
# Out:
# {1, 2, 3, 4, 'Lima', 6, 'tujuh', 8}

# %% [markdown]
# ### Operasi Sets
# <img src="https://cdn-images-1.medium.com/max/1200/0*a02OPI3-TnbKXyub.png" width=300>

# %%
a={1,2,3,4}
b={2,3,5,6}
print(a.union(b))
print(a|b)
# Out:
# {1, 2, 3, 4, 5, 6}
# {1, 2, 3, 4, 5, 6}

# %%
print(a.intersection(b))
print(a&b)
# Out:
# {2, 3}
# {2, 3}

# %%
print(a.difference(b))
print(a-b)
print(b.difference(a))
print(b-a)
# Out:
# {1, 4}
# {1, 4}
# {5, 6}
# {5, 6}

# %%
print(a.symmetric_difference(b))
print(a^b)
# Out:
# {1, 4, 5, 6}
# {1, 4, 5, 6}

# %% [markdown]
# # Latihan
# <br>
# <img src="https://media.matamata.com/thumbs/2021/03/22/73000-irene-sukandar-vs-dewa-kipas-youtubecom/o-img-73000-irene-sukandar-vs-dewa-kipas-youtubecom.jpg" width=250>
# <br>
#
# - Carilah gabungan, irisan, dan elemen gabungan diluar irisan

# %%
a={"Human","Cyborg","Animal","Plant"}
b={"Human","Devil","Mutant","Plant"}


#put your code
gabungan = a|b
irisan = a&b
elemen_gdi = a^b

print(gabungan)
print(irisan)
print(elemen_gdi)
# Out:
# {'Plant', 'Human', 'Animal', 'Devil', 'Mutant', 'Cyborg'}
# {'Plant', 'Human'}
# {'Cyborg', 'Devil', 'Mutant', 'Animal'}

# %% [markdown]
# # Control Flow
# - merupakan kontrol aliran dari suatu program
# - menggunakan if Statements

# %% [markdown]
# ## Comparison Operators
# <img src="https://iconicdevelopers.com/wp-content/uploads/2019/01/Overview-of-Comparison-Operators-in-Python-1024x603.png" width=350>

# %%
print(2 < 1)
print(2 > 1)
print(2 >= 2)
print("Python" == "python")
print("Python" != "python")
print(True==1)
print(False==0)
# Out:
# False
# True
# True
# False
# True
# True
# True

# %% [markdown]
# ## If Statements

# %%
if 2 > 1:
  print("benar")
# Out:
# benar

# %%
karakter="Nobita"

if karakter == "Nobita":
  print("Karakter Utama")
else:
  print("Karakter Sampingan")
# Out:
# Karakter Utama

# %%
bmi=60
if bmi >=80:
  print("Obesitas")
elif bmi >=70:
  print("Gemuk")
else:
  print("Ideal")
# Out:
# Ideal

# %%
if bmi >=70:
  print("Obesitas")
elif bmi >=60:
  print("Gemuk")
else:
  print("Ideal")
# Out:
# Gemuk

# %%
karakter=["nobita","doraemon"]

if "nobita" in karakter:
  print("ada")
else:
  print("tidak ada")
# Out:
# ada

# %% [markdown]
# ## Nested If Statements
# <img src="https://2.bp.blogspot.com/-mx64B9NtRSA/WfSKCIzk_nI/AAAAAAAAAQ0/kRTiARbdwMEDF7I88_nDS-HrMN02igs7gCLcBGAs/s1600/algo.png">

# %%
karakter=["nobita","doraemon"]

if "nobita" in karakter and "doraemon" in karakter:
  print("ada")

if "nobita" in karakter:
  if "doraemon" in karakter:
    print("ada")
# Out:
# ada
# ada

# %%
dewa_kipas="kalah"
cara_kalah="checkmate"

if dewa_kipas == "kalah":
  if cara_kalah=="checkmate":
    print("ga dapet 100 juta")
    print("Irene dapet 200 juta")
  elif cara_kalah=="surrender":
    print("dapet 100 juta")
    print("Irene dapet 200 juta")
  else:
    print("deddy cahyadi untung banyak")
elif dewa_kipas=="menang":
  print("dewa kipas dapet 200 juta")
  print("deddy cahyadi tetep untung banyak")
else:
  print("salah input")
# Out:
# ga dapet 100 juta
# Irene dapet 200 juta

# %% [markdown]
# # Latihan
# <br>
# <img src="https://media.matamata.com/thumbs/2021/03/22/73000-irene-sukandar-vs-dewa-kipas-youtubecom/o-img-73000-irene-sukandar-vs-dewa-kipas-youtubecom.jpg" width=250>
# <br>
#
# Buatlah program lampu lalu lintas, dengan ketentuan
#
# - Jika lampu berwarna hijau maka tampilkan Jalan
# - Jika lampu berwarna kuning maka tampilkan Bersiap
# - Jika lampu berwarna merah maka tampilkan Berhenti

# %%
lampu=""
#put your code
lampu  = str(input())
if lampu == "hijau":
  print("Jalan")
elif lampu == "kuning":
  print("Bersiap")
elif lampu == "merah":
  print("Berhenti")
# Out:
# kuning
# Bersiap
