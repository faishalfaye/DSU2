# %%
import psycopg2 as pg
import pandas as pd

conn = pg.connect(database="latihan",
                 user="postgres",
                 password="ashalandorei",
                 host="127.0.0.1",
                 port="5432")

def run(query):
    df = pd.read_sql(query,conn)
    return df

# %% [markdown]
# # 1. Prepare a list of offices sorted by country, state, city.

# %%
run("""
SELECT COUNTRY, STATE, CITY
FROM _OFFICES
""")
# Out:
#      country       state           city
# 0        USA          CA  San Francisco
# 1        USA          MA         Boston
# 2        USA          NY            NYC
# 3     France                      Paris
# 4      Japan  Chiyoda-Ku          Tokyo
# 5  Australia                     Sydney
# 6         UK                     London

# %% [markdown]
# # 2. How many employees are there in the company?

# %%
run("""
SELECT *
FROM _employees
""")
# Out:
#     employeenumber   lastname firstname extension  \
# 0             1002     Murphy     Diane     x5800
# 1             1056  Patterson      Mary     x4611
# 2             1076   Firrelli      Jeff     x9273
# 3             1088  Patterson   William     x4871
# 4             1102     Bondur    Gerard     x5408
# 5             1143        Bow   Anthony     x5428
# 6             1165   Jennings    Leslie     x3291
# 7             1166   Thompson    Leslie     x4065
# 8             1188   Firrelli     Julie     x2173
# 9             1216  Patterson     Steve     x4334
# 10            1286      Tseng  Foon Yue     x2248
# 11            1323     Vanauf    George     x4102
# 12            1337     Bondur      Loui     x6493
# 13            1370  Hernandez    Gerard     x2028
# 14            1401   Castillo    Pamela     x2759
# 15            1501       Bott     Larry     x2311
# 16            1504      Jones     Barry      x102
# 17            1611     Fixter      Andy      x101
# ...

# %% [markdown]
# There are 23 employees in the company

# %% [markdown]
# # 3. What is the total of payments received?

# %%
run("""
SELECT SUM(amount)
FROM _payments
""")
# Out:
#           sum
# 0  8853839.23

# %% [markdown]
# # 4. List the product lines that contain 'Cars'

# %%
run("""
SELECT *
FROM _productlines
WHERE productline = 'Classic Cars' OR productline = 'Vintage Cars'
""")
# Out:
#     productline                                    textdescription  \
# 0  Classic Cars  Attention car enthusiasts: Make your wildest c...
# 1  Vintage Cars  Our Vintage Car models realistically portray a...
#
#   htmldescription image
# 0
# 1

# %%
run("""
SELECT *
FROM _products
WHERE productline LIKE '%Cars%'
""")
# Out:
#    productcode                   productname   productline productscale  \
# 0     S10_1949      1952 Alpine Renault 1300  Classic Cars         1:10
# 1     S10_4757           1972 Alfa Romeo GTA  Classic Cars         1:10
# 2     S10_4962        1962 LanciaA Delta 16V  Classic Cars         1:10
# 3     S12_1099             1968 Ford Mustang  Classic Cars         1:12
# 4     S12_1108             2001 Ferrari Enzo  Classic Cars         1:12
# ..         ...                           ...           ...          ...
# 57    S24_4258         1936 Chrysler Airflow  Vintage Cars         1:24
# 58    S24_4620         1961 Chevrolet Impala  Classic Cars         1:18
# 59    S32_4289      1928 Ford Phaeton Deluxe  Vintage Cars         1:32
# 60    S50_1341  1930 Buick Marquette Phaeton  Vintage Cars         1:50
# 61   S700_2824               1982 Camaro Z28  Classic Cars         1:18
#
#                productvendor  \
# 0    Classic Metal Creations
# 1    Motor City Art Classics
# ...

# %% [markdown]
# # 5. Report total payments for October 28, 2004

# %%
run("""
SELECT SUM(amount)
FROM _payments
WHERE paymentdate = '2004-10-28'
""")
# Out:
#         sum
# 0  47411.33

# %% [markdown]
# # 6. Report those payments greater than 100000

# %%
run("""
SELECT *
FROM _payments
WHERE amount > 100000
""")
# Out:
#    customernumber checknumber paymentdate     amount
# 0             124    AE215433  2005-03-05  101244.59
# 1             124    KI131716  2003-08-15  111654.40
# 2             141     ID10962  2004-12-31  116208.40
# 3             141    JE105477  2005-03-18  120166.58
# 4             148    KM172879  2003-12-26  105743.00

# %% [markdown]
# # 7. List the products in each product line

# %%
run("""
SELECT productline, productname
FROM _products
GROUP BY productline, productname
ORDER BY productline ASC
""")
# Out:
#       productline                                productname
# 0    Classic Cars                1948 Porsche 356-A Roadster
# 1    Classic Cars             1948 Porsche Type 356 Roadster
# 2    Classic Cars                         1949 Jaguar XK 120
# 3    Classic Cars                   1952 Alpine Renault 1300
# 4    Classic Cars                          1952 Citroen-15CV
# ..            ...                                        ...
# 105  Vintage Cars  1938 Cadillac V-16 Presidential Limousine
# 106  Vintage Cars                    1939 Cadillac Limousine
# 107  Vintage Cars                1939 Chevrolet Deluxe Coupe
# 108  Vintage Cars                   1940 Ford Delivery Sedan
# 109  Vintage Cars    1941 Chevrolet Special Deluxe Cabriolet
#
# [110 rows x 2 columns]

# %%
run("""
SELECT productline, productname
FROM _products
WHERE productline = 'Classic Cars'
""")
# Out:
#      productline                          productname
# 0   Classic Cars             1952 Alpine Renault 1300
# 1   Classic Cars                  1972 Alfa Romeo GTA
# 2   Classic Cars               1962 LanciaA Delta 16V
# 3   Classic Cars                    1968 Ford Mustang
# 4   Classic Cars                    2001 Ferrari Enzo
# 5   Classic Cars                   1969 Corvair Monza
# 6   Classic Cars                   1968 Dodge Charger
# 7   Classic Cars                     1969 Ford Falcon
# 8   Classic Cars              1970 Plymouth Hemi Cuda
# 9   Classic Cars                   1969 Dodge Charger
# 10  Classic Cars                      1993 Mazda RX-7
# 11  Classic Cars                1965 Aston Martin DB5
# 12  Classic Cars          1948 Porsche 356-A Roadster
# 13  Classic Cars                     1995 Honda Civic
# 14  Classic Cars       1998 Chrysler Plymouth Prowler
# 15  Classic Cars         1999 Indy 500 Monte Carlo SS
# ...

# %%
run("""
SELECT productline, productname
FROM _products
WHERE productline = 'Motorcycles'
""")
# Out:
#     productline                            productname
# 0   Motorcycles  1969 Harley Davidson Ultimate Chopper
# 1   Motorcycles                  1996 Moto Guzzi 1100i
# 2   Motorcycles   2003 Harley-Davidson Eagle Drag Bike
# 3   Motorcycles                       2002 Suzuki XREO
# 4   Motorcycles    1936 Harley Davidson El Knucklehead
# 5   Motorcycles                       1957 Vespa GS150
# 6   Motorcycles                      1997 BMW R 1100 S
# 7   Motorcycles               1960 BSA Gold Star DBD34
# 8   Motorcycles                1982 Ducati 900 Monster
# 9   Motorcycles                       1997 BMW F650 ST
# 10  Motorcycles                      1982 Ducati 996 R
# 11  Motorcycles              1974 Ducati 350 Mk3 Desmo
# 12  Motorcycles                     2002 Yamaha YZR M1

# %%
run("""
SELECT productline, productname
FROM _products
WHERE productline = 'Planes'
""")
# Out:
#    productline                       productname
# 0       Planes       1980s Black Hawk Helicopter
# 1       Planes                  Boeing X-32A JSF
# 2       Planes                    P-51-D Mustang
# 3       Planes  1928 British Royal Navy Airplane
# 4       Planes            1900s Vintage Bi-Plane
# 5       Planes          Corsair F4U ( Bird Cage)
# 6       Planes           1900s Vintage Tri-Plane
# 7       Planes       American Airlines: B767-300
# 8       Planes    America West Airlines B757-200
# 9       Planes                     ATA: B757-300
# 10      Planes                F/A 18 Hornet 1/72
# 11      Planes         American Airlines: MD-11S

# %%
run("""
SELECT productline, productname
FROM _products
WHERE productline = 'Ships'
""")
# Out:
#   productline                productname
# 0       Ships     1999 Yamaha Speed Boat
# 1       Ships      18th century schooner
# 2       Ships      The Schooner Bluenose
# 3       Ships              The Mayflower
# 4       Ships                 HMS Bounty
# 5       Ships  The USS Constitution Ship
# 6       Ships                The Titanic
# 7       Ships             The Queen Mary
# 8       Ships                 Pont Yacht

# %%
run("""
SELECT productline, productname
FROM _products
WHERE productline = 'Trains'
""")
# Out:
#   productline                             productname
# 0      Trains                Collectable Wooden Train
# 1      Trains  1950's Chicago Surface Lines Streetcar
# 2      Trains          1962 City of Detroit Streetcar

# %%
run("""
SELECT productline, productname
FROM _products
WHERE productline = 'Trucks and Buses'
""")
# Out:
#          productline                                  productname
# 0   Trucks and Buses                               1958 Setra Bus
# 1   Trucks and Buses                            1957 Chevy Pickup
# 2   Trucks and Buses                       1940 Ford Pickup Truck
# 3   Trucks and Buses                       1964 Mercedes Tour Bus
# 4   Trucks and Buses                        1926 Ford Fire Engine
# 5   Trucks and Buses                             1940s Ford truck
# 6   Trucks and Buses                     1962 Volkswagen Microbus
# 7   Trucks and Buses                  1980’s GM Manhattan Express
# 8   Trucks and Buses                  1954 Greyhound Scenicruiser
# 9   Trucks and Buses  1996 Peterbilt 379 Stake Bed with Outrigger
# 10  Trucks and Buses             Diamond T620 Semi-Skirted Tanker

# %%
run("""
SELECT productline, productname
FROM _products
WHERE productline = 'Vintage Cars'
""")
# Out:
#      productline                                productname
# 0   Vintage Cars                       1937 Lincoln Berline
# 1   Vintage Cars   1936 Mercedes-Benz 500K Special Roadster
# 2   Vintage Cars                   1917 Grand Touring Sedan
# 3   Vintage Cars                         1911 Ford Town Car
# 4   Vintage Cars                  1932 Model A Ford J-Coupe
# 5   Vintage Cars                     1928 Mercedes-Benz SSK
# 6   Vintage Cars                1913 Ford Model T Speedster
# 7   Vintage Cars                         1934 Ford V8 Coupe
# 8   Vintage Cars        18th Century Vintage Horse Carriage
# 9   Vintage Cars                          1903 Ford Model A
# 10  Vintage Cars                   1917 Maxwell Touring Car
# 11  Vintage Cars    1941 Chevrolet Special Deluxe Cabriolet
# 12  Vintage Cars        1932 Alfa Romeo 8C2300 Spider Sport
# 13  Vintage Cars                        1904 Buick Runabout
# 14  Vintage Cars                    1939 Cadillac Limousine
# ...

# %% [markdown]
# # 8. How many products in each product line?

# %% [markdown]
# SELECT ClientID, ServerID, MAX(`Last.Date`) AS `Last.Date`, COUNT(*) AS ConnectionCount
# FROM YourTable
# GROUP BY ClientID, ServerID

# %%
run("""
SELECT productline, COUNT(productline)
FROM _products
GROUP BY productline
""")
# Out:
#         productline  count
# 0      Classic Cars     38
# 1            Trains      3
# 2            Planes     12
# 3  Trucks and Buses     11
# 4      Vintage Cars     24
# 5       Motorcycles     13
# 6             Ships      9

# %% [markdown]
# # 9. What is the minimum payment received?

# %%
run("""
SELECT MIN(amount)
FROM _payments
""")
# Out:
#       min
# 0  615.45

# %% [markdown]
# The minimum payment received is 615.45

# %% [markdown]
# # 10. Which orders have a value greater than 5,000?

# %%
run("""
SELECT ordernumber
FROM _orders
WHERE EXISTS (SELECT amount FROM _payments WHERE amount > 5000)
""")
# Out:
#      ordernumber
# 0          10100
# 1          10101
# 2          10102
# 3          10103
# 4          10104
# ..           ...
# 321        10421
# 322        10422
# 323        10423
# 324        10424
# 325        10425
#
# [326 rows x 1 columns]

# %%
run("""
SELECT ordernumber
FROM _orders
WHERE EXISTS (SELECT checknumber FROM _payments WHERE _orders.customernumber = _payments.customernumber AND amount > 5000)
""")
# Out:
#      ordernumber
# 0          10100
# 1          10101
# 2          10102
# 3          10103
# 4          10104
# ..           ...
# 319        10421
# 320        10422
# 321        10423
# 322        10424
# 323        10425
#
# [324 rows x 1 columns]
