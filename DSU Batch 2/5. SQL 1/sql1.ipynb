# %%
import psycopg2 as pg
import pandas as pd

conn = pg.connect( host='localhost', user='usernamemu', password='passwordmu', dbname='contoh_db')

def run(query):
    df = pd.read_sql(query,conn)
    return df

# %% [markdown]
# # SELECT

# %%
run("""SELECT * 
        FROM COMPANY""")
# Out:
#    id   name  age                                            address   salary  \
# 0   1   Paul   32  California                                    ...  20000.0
# 1   2  Allen   25  Texas                                         ...      NaN
# 2   3  Teddy   23  Norway                                        ...  20000.0
# 3   4   Mark   25  Rich-Mond                                     ...  65000.0
# 4   5  David   27  Texas                                         ...  85000.0
# 5   6   Alex   27  Silicon-Valley                                ...  31000.0
# 6   7   Raul   22  New-York                                      ...  23000.0
# 7   8   Paul   24  Houston                                       ...  20000.0
# 8   9  James   44  Norway                                        ...   5000.0
# 9  10  James   45  Texas                                         ...   5000.0
#
#     join_date
# 0  2001-07-13
# 1  2007-12-13
# 2        None
# 3  2007-12-13
# 4  2007-12-13
# 5  2003-01-01
# ...

# %% [markdown]
# ## isi exercise A pada ppt

# %%
run("""
query
""")
# Out:
#    id   name   salary
# 0   1   Paul  20000.0
# 1   2  Allen      NaN
# 2   3  Teddy  20000.0
# 3   4   Mark  65000.0
# 4   5  David  85000.0

# %% [markdown]
# # WHERE

# %% [markdown]
# ## isi exercise B pada ppt

# %%
run("""
query
""")

# %% [markdown]
# # LIKE

# %% [markdown]
# ## isi exercise C pada ppt

# %%
run("""
query
""")

# %% [markdown]
# # LIMIT

# %% [markdown]
# ## isi exercise D pada ppt

# %%
run("""
query
""")

# %% [markdown]
# # ORDER

# %% [markdown]
# ## isi exercise E pada ppt

# %%
run("""
query
""")

# %% [markdown]
# # DISTINCT

# %% [markdown]
# ## isi exercise F pada ppt

# %%
run("""
query
""")
# Out:
#     name
# 0  Teddy
# 1   Raul
# 2  David
# 3   Paul
# 4   Alex
# 5   Mark
# 6  Allen
# 7  James

# %% [markdown]
# # GROUP

# %% [markdown]
# ## isi exercise G pada ppt

# %%
run("""
query
""")
